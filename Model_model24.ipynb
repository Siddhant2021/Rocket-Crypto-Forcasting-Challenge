# %%
import pandas as pd  
import numpy as np
import seaborn as sns

# %%
train=pd.read_csv("dataset/train_dataset.csv")
train.head()
# Out:
#          date symbol  feature_1  feature_2  feature_3  feature_4  feature_5  \
# 0  2018-04-29    BTC   0.000000   0.000000   0.965517   0.000000   0.000000
# 1  2018-04-29    DLT   0.310345   0.310345   0.137931   0.275862   0.206897
# 2  2018-04-29    ENJ   0.241379   0.068966   0.310345   0.344828   0.103448
# 3  2018-04-29    OMG   0.758621   0.965517   0.896552   0.965517   0.965517
# 4  2018-04-29    UFR   0.620690   0.413793   0.275862   0.413793   0.517241
#
#    feature_6  feature_7  feature_8  ...  feature_2003  feature_2004  \
# 0   0.000000   0.000000   0.000000  ...      0.689655      0.655172
# 1   0.517241   0.344828   0.689655  ...      0.206897      0.206897
# 2   0.103448   0.379310   0.206897  ...      0.379310      0.344828
# 3   0.965517   0.068966   0.275862  ...      0.896552      0.931034
# 4   0.362069   0.758621   0.586207  ...      0.482759      0.275862
#
#    feature_2005  feature_2006  feature_2007  feature_2008  feature_2009  \
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/siddhant/Downloads/rocket crypto/t.ipynb Cell 3 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/siddhant/Downloads/rocket%20crypto/t.ipynb#X50sZmlsZQ%3D%3D?line=0'>1</a> uniquerow
#
# NameError: name 'uniquerow' is not defined

# %%
symbols=train['symbol'].unique()

symbols
# Out:
# array(['BTC', 'DLT', 'ENJ', 'OMG', 'UFR', 'VGX', 'DRGN', 'BAT', 'AGIX',
#        'KEY', 'KNC', 'TRAC', 'PRO', 'PLAY', 'PAY', 'DCN', 'DAY', 'CAN',
#        'XRP', 'SRN', 'SALT', 'REQ', 'QSP', 'TRST', 'USDT', 'MGO', 'GET',
#        'FUN', 'PRE', 'ETH', 'SPANK', 'ZRX', 'POLL', 'FUEL', 'ANT', 'AST',
#        'SNGLS', 'VEE', 'VIB', 'PLR', 'BRD', 'WABI', 'MTL', 'NGC', 'IDH',
#        'VIBE', 'PPT', 'DADI', 'DNT', 'GNO', 'POWR', 'DENT', 'GRID', 'OCN',
#        'WPR', 'MANA', 'EVE', 'DNA', 'DGD', 'WTC', 'GVT', 'CDT', 'GLM',
#        'POLY', 'RCN', 'EXRN', 'MTN', 'TKN', 'AXP', 'CRPT', 'HGT', 'LOC',
#        'PRG', 'ENG', 'TEL', 'TNB', 'PLBT', 'POE', 'ELF', 'ATL', 'MKR',
#        'PPP', 'UTK', 'CND', 'MCO', 'LUN', 'REM', 'ABT', 'RDN', 'CHP',
#        'SNT', 'STORM', 'ELEC', 'BKX', 'NCASH', 'QASH', 'CAS', 'SHIP',
#        'SAN', 'BNT', 'DMT', 'STAR', 'BANCA', 'ZAP', 'SAI', 'IND', 'BERRY',
#        'NCT', 'RFR', 'B2B', 'BLZ', 'TEN', 'MTH', 'HT', 'MWAT', 'BAX',
# ...

# %%
count=0
for (uniquerow), group in train.groupby(train.symbol):
    count+=1
    globals()['df' + str(count)] = group

# %%
# Out:
# 980

# %%
for i in symbols :
    i=train[train['symbol']=='i']
    i.head()

# %%
top=train['symbol'].value_counts()
top.head(20)
# Out:
# BTC     224
# REQ     224
# SRN     224
# PAY     224
# GNO     223
# PPT     223
# WABI    223
# PRO     222
# ETH     222
# AGIX    222
# POWR    221
# VIBE    221
# CRPT    221
# VIB     221
# KEY     220
# FUN     220
# RCN     220
# MTN     220
# MANA    220
# ENJ     220
# Name: symbol, dtype: int64

# %%
gc=(train['symbol'].value_counts()>223)
gc[gc==True].count()
# Out:
# 4

# %%
BTC=train[train['symbol']=='BTC']
# train=train.drop(BTC,axis=0)
train=train[~train['symbol'].isin(['BTC'])]
train
# Out:
#              date symbol  feature_1  feature_2  feature_3  feature_4  \
# 1      2018-04-29    DLT   0.310345   0.310345   0.137931   0.275862
# 2      2018-04-29    ENJ   0.241379   0.068966   0.310345   0.344828
# 3      2018-04-29    OMG   0.758621   0.965517   0.896552   0.965517
# 4      2018-04-29    UFR   0.620690   0.413793   0.275862   0.413793
# 5      2018-04-29    VGX   0.793103   0.758621   0.517241   0.500000
# ...           ...    ...        ...        ...        ...        ...
# 86080  2022-08-07   COMP   0.958924   0.956091   0.142351   0.079320
# 86081  2022-08-07    BAL   0.838527   0.966714   0.973088   0.981586
# 86082  2022-08-07    XOR   0.337819   0.696176   0.096317   0.769122
# 86083  2022-08-07   YFII   0.038244   0.043201   0.119688   0.052408
# 86084  2022-08-07   USTC   0.064448   0.092068   0.016997   0.033994
#
#        feature_5  feature_6  feature_7  feature_8  ...  feature_2003  \
# ...

# %%
train.describe()
# Out:
#           feature_1     feature_2     feature_3     feature_4     feature_5  \
# count  86085.000000  86085.000000  86085.000000  86085.000000  86085.000000
# mean       0.500000      0.500000      0.500000      0.500000      0.500000
# std        0.287654      0.287764      0.287854      0.287889      0.287945
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.250392      0.250435      0.250000      0.250000      0.250000
# 50%        0.500000      0.500000      0.504941      0.500000      0.506148
# 75%        0.748588      0.747135      0.746429      0.748244      0.747175
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#           feature_6     feature_7     feature_8     feature_9    feature_10  \
# count  86085.000000  86085.000000  86085.000000  86085.000000  86085.000000
# mean       0.500000      0.500000      0.500000      0.500000      0.500000
# ...

# %%
train['symbol']
# Out:
# 86085

# %%
train['symbol'].nunique()
# Out:
# 980

# %%
BTC=train[train['symbol']=='BTC']
BTC
# Out:
#              date symbol  feature_1  feature_2  feature_3  feature_4  \
# 0      2018-04-29    BTC        0.0        0.0   0.965517   0.000000
# 84     2018-05-06    BTC        1.0        0.0   0.981481   1.000000
# 146    2018-05-13    BTC        1.0        1.0   1.000000   1.000000
# 184    2018-05-20    BTC        0.0        0.0   0.988636   0.000000
# 267    2018-05-27    BTC        0.0        0.0   0.000000   0.989362
# ...           ...    ...        ...        ...        ...        ...
# 82818  2022-07-10    BTC        0.0        0.0   0.000000   0.000000
# 83968  2022-07-17    BTC        1.0        1.0   1.000000   0.997122
# 84418  2022-07-24    BTC        0.0        1.0   1.000000   1.000000
# 85202  2022-07-31    BTC        0.0        0.0   0.998586   0.998586
# 85842  2022-08-07    BTC        1.0        0.0   0.000000   1.000000
#
#        feature_5  feature_6  feature_7  feature_8  ...  feature_2003  \
# ...

# %%
cor_array = []
for i in range (1,2010):
    cor_array.append(BTC['feature_'+ str(i)].corr(BTC['target']))

# %%
cor_array = np.absolute(np.array(cor_array))
print(cor_array)
# Out:
# [0.05835211 0.00655023 0.00972051 ... 0.089489   0.1005595  0.08592458]

# %%
ss=np.arange(1,2010)
pf=pd.DataFrame({'index':ss,'Cor':cor_array})



pf
# Out:
#       index       Cor
# 0         1  0.058352
# 1         2  0.006550
# 2         3  0.009721
# 3         4  0.003937
# 4         5  0.095973
# ...     ...       ...
# 2004   2005  0.097024
# 2005   2006  0.091620
# 2006   2007  0.089489
# 2007   2008  0.100559
# 2008   2009  0.085925
#
# [2009 rows x 2 columns]

# %%
gg=pf[(pf['Cor']>.2) |(pf['Cor']<-.2)]
# gh=gg[(gg['Cor']<-.05)]
gg
# Out:
#       index       Cor
# 57       58  0.209486
# 439     440  0.200021
# 691     692  0.202892
# 693     694  0.230577
# 695     696  0.202279
# 699     700  0.255026
# 709     710  0.259950
# 719     720  0.245341
# 1016   1017  0.215785
# 1388   1389  0.209851
# 1397   1398  0.201094
# 1398   1399  0.200732
# 1399   1400  0.213951
# 1405   1406  0.252069
# 1407   1408  0.206716
# 1409   1410  0.220133
# 1465   1466  0.200264
# 1741   1742  0.205998
# 1750   1751  0.254170
# 1752   1753  0.237613
# 1777   1778  0.217731
# 1779   1780  0.219727

# %%
# from sklearn import preprocessing
# le = preprocessing.LabelEncoder()
# train["symbol"] = le.fit_transform(train["symbol"])
# X=train['symbol']
# Y=train['feature_1']
# # Y=train.drop(['date','symbol','feature_DC1','target','target_DC1'],axis=1)
# Z=train['target']
# df=pd.DataFrame({'symbol':X,'feature':Y,'target':Z})
# # df2=df.pivot(index='symbol',columns='feature',values='target')
# sns.heatmap(df)

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
BTC["symbol"] = le.fit_transform(BTC["symbol"])
X=BTC.drop(['date'],axis=1)
sns.heatmap(X)
# Out:
# /var/folders/gj/6w82t4757zjcl7v6tv4k4xdc0000gn/T/ipykernel_28638/1266661767.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BTC["symbol"] = le.fit_transform(BTC["symbol"])
# <AxesSubplot:>

# %%
df=train.drop(['date','symbol','feature_DC1','target_DC1'],axis=1)
# W=train['target']
# df=pd.concat([W,Y])
df
# Out:
#        feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# 0       0.000000   0.000000   0.965517   0.000000   0.000000   0.000000
# 1       0.310345   0.310345   0.137931   0.275862   0.206897   0.517241
# 2       0.241379   0.068966   0.310345   0.344828   0.103448   0.103448
# 3       0.758621   0.965517   0.896552   0.965517   0.965517   0.965517
# 4       0.620690   0.413793   0.275862   0.413793   0.517241   0.362069
# ...          ...        ...        ...        ...        ...        ...
# 86080   0.958924   0.956091   0.142351   0.079320   0.065156   0.049575
# 86081   0.838527   0.966714   0.973088   0.981586   0.984419   0.950425
# 86082   0.337819   0.696176   0.096317   0.769122   0.849858   0.844901
# 86083   0.038244   0.043201   0.119688   0.052408   0.039660   0.008499
# 86084   0.064448   0.092068   0.016997   0.033994   0.004249   0.784703
#
#        feature_7  feature_8  feature_9  feature_10  ...  feature_2001  \
# ...

# %%
import numpy as np

# Create correlation matrix
corr_matrix = df.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find features with correlation greater than 0.95
to_drop = [column for column in upper.columns if any((upper[column] <-0.95) )]
to_drop = [column for column in upper.columns if any((upper[column] > 0.95)  )]


# Drop features 
df.drop(to_drop, axis=1, inplace=True)
df

# %%
sns.heatmap(df)
# Out:
# <AxesSubplot:>

# %%
cor_array = []
for i in range (1,2009):
        cor_array.append(train['feature_'+ str(i)].corr(train['feature_'+ str(i+1)]))

# %%
cor_array = np.absolute(np.array(cor_array))

print(cor_array)
# Out:
# [0.47098301 0.52168615 0.55022243 ... 0.7821662  0.98802022 0.91200583]

# %%
ss=np.arange(1,2009)
pf=pd.DataFrame({'index':ss,'Cor':cor_array})


# pf=pd.DataFrame.set_index()
pf
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/siddhant/Downloads/rocket crypto/t.ipynb Cell 14 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/siddhant/Downloads/rocket%20crypto/t.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> ss1=np.arange(1,448)
# ----> <a href='vscode-notebook-cell:/Users/siddhant/Downloads/rocket%20crypto/t.ipynb#X15sZmlsZQ%3D%3D?line=1'>2</a> pf=pd.DataFrame({'index':ss,'Cor':cor_array})
#       <a href='vscode-notebook-cell:/Users/siddhant/Downloads/rocket%20crypto/t.ipynb#X15sZmlsZQ%3D%3D?line=4'>5</a> # pf=pd.DataFrame.set_index()
#       <a href='vscode-notebook-cell:/Users/siddhant/Downloads/rocket%20crypto/t.ipynb#X15sZmlsZQ%3D%3D?line=5'>6</a> pf
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:636, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     630     mgr = self._init_mgr(
# ...

# %%
gg=pf[(pf['Cor']<.007)]
gh=gg[(gg['Cor']>-.007)]
gg

# gh.info()
# Out:
#       index       Cor
# 89       90  0.005953
# 119     120  0.002828
# 329     330  0.006287
# 539     540  0.006562
# 559     560  0.000948
# 569     570  0.003204
# 679     680  0.001232
# 749     750  0.000429
# 869     870  0.004667
# 899     900  0.004275
# 1109   1110  0.000138
# 1129   1130  0.004063
# 1139   1140  0.001620
# 1379   1380  0.001392
# 1399   1400  0.003533
# 1489   1490  0.005899
# 1529   1530  0.002203
# 1639   1640  0.000100

# %%
gh
# Out:
#       index       Cor
# 89       90  0.005953
# 119     120  0.002828
# 329     330  0.006287
# 539     540  0.006562
# 559     560  0.000948
# 569     570  0.003204
# 679     680  0.001232
# 749     750  0.000429
# 869     870  0.004667
# 899     900  0.004275
# 1109   1110  0.000138
# 1129   1130  0.004063
# 1139   1140  0.001620
# 1379   1380  0.001392
# 1399   1400  0.003533
# 1489   1490  0.005899
# 1529   1530  0.002203
# 1639   1640  0.000100

# %%
cor_array = []
for i in range (1,2009):
    cor_array.append(df['feature_'+ str(i)].corr(df['target']))

# %%
cor_array
# Out:
# [-0.0013497036642486908,
#  -0.0036944509097932166,
#  -0.0005742676899850454,
#  -0.005406357086192854,
#  -0.006300633131640288,
#  -0.008260534256569725,
#  -0.00683898424056905,
#  -0.011499896904295166,
#  -0.01355614211948091,
#  -0.012479836856796952,
#  0.0010894859911497535,
#  0.0033463350368518547,
#  0.003986446998252369,
#  -0.0012729300733817276,
#  -0.002399155287031133,
#  -0.003296877426306272,
#  -0.0005906042973679268,
#  -0.006939508350581004,
#  -0.008402641269157794,
#  -0.007938665387336933,
#  -0.0062031668095234626,
#  -0.011357073826318953,
#  -0.007669324967017155,
#  -0.009624447756253244,
#  -0.010503067785055518,
#  -0.012549430043016539,
#  -0.010546452979707344,
#  -0.009866743357826765,
#  -0.01789801866440136,
#  -0.012465981489566827,
#  -0.0036266241258680635,
#  -0.0003358462225596397,
#  -0.0033278285058284274,
#  -0.01020583269413839,
#  -0.008047123048549546,
#  -0.011400294213834886,
#  -0.01077023681533612,
#  -0.01632967325035805,
# ...

# %%
ss1=np.arange(1,2009)
btccor=pd.DataFrame({'index':ss1,'Cor':cor_array})
bt=btccor[(btccor['Cor']>.05) | (btccor['Cor']<-.05)]
# bt1=bt[(bt['Cor']<-.0001)]
bt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 73 entries, 1748 to 1996
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   index   73 non-null     int64
#  1   Cor     73 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 1.7 KB

# %%
# bt1['index'].to_csv('fea.csv')
# sns.heatmap()
# Out:
# <AxesSubplot:>

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   index   0 non-null      int64
#  1   Cor     0 non-null      float64
# dtypes: float64(1), int64(1)
# memory usage: 0.0 bytes

# %%
if(df['symbol']=='BTC'):
    y_pred= lstm_BTC.predict(X_test)
elif(df['symbol']=='REQ'):
    y_pred= lstm_REQ.predict(X_test)
elif(df['symbol']=='SRN'):
    y_pred= lstm_SRN.predict(X_test)
elif(df['symbol']=='PAY'):
    y_pred= lstm_PAY.predict(X_test)
elif(df['symbol']=='GNO'):
    y_pred= lstm_GNO.predict(X_test)
elif(df['symbol']=='PPT'):
    y_pred= lstm_PPT.predict(X_test)
elif(df['symbol']=='WABI'):
    y_pred= lstm_WABI.predict(X_test)
elif(df['symbol']=='PRO'):
    y_pred= lstm_PRO.predict(X_test)
elif(df['symbol']=='ETH'):
    y_pred= lstm_ETH.predict(X_test)
elif(df['symbol']=='AGIX'):
    y_pred= lstm_AGIX.predict(X_test)
elif(df['symbol']=='POWR'):
    y_pred= lstm_POWR.predict(X_test)
elif(df['symbol']=='VIBE'):
    y_pred= lstm_VIBE.predict(X_test)
elif(df['symbol']=='CRPT'):
    y_pred= lstm_CRPT.predict(X_test)
elif(df['symbol']=='VIB'):
    y_pred= lstm_VIB.predict(X_test)
elif(df['symbol']=='KEY'):
    y_pred= lstm_KEY.predict(X_test)
elif(df['symbol']=='FUN'):
    y_pred= lstm_FUN.predict(X_test)
elif(df['symbol']=='RCN'):
    y_pred= lstm_RCN.predict(X_test)
elif(df['symbol']=='MTN'):
    y_pred= lstm_MTN.predict(X_test)
elif(df['symbol']=='MANA'):
    y_pred= lstm_MANA.predict(X_test)
elif(df['symbol']=='ENJ'):
    y_pred= lstm_ENJ.predict(X_test)
elif(df['symbol']=='POLY'):
    y_pred= lstm_POLY.predict(X_test)
elif(df['symbol']=='DRGN'):
    y_pred= lstm_DRGN.predict(X_test)
else:
    y_pred= lstm.predict(X_test)

# %%
output_var = pd.DataFrame(BTC['target'])

features = ['feature_58', 'feature_440','feature_692','feature_694','feature_696','feature_700','feature_710','feature_720','feature_1017','feature_1389','feature_1398','feature_1399','feature_1400','feature_1406','feature_1408','feature_1410','feature_1466','feature_1742','feature_1751','feature_1753','feature_1778','feature_1780']
#Scaling

scaler = MinMaxScaler()
feature_transform = scaler.fit_transform(BTC[features])
feature_transform= pd.DataFrame(columns=features, data=feature_transform, index=BTC.index)
feature_transform.head()

timesplit= TimeSeriesSplit(n_splits=10)
for train_index, test_index in timesplit.split(feature_transform):
        BTC_train, BTC_test = feature_transform[:len(train_index)], feature_transform[len(train_index): (len(train_index)+len(test_index))]
        BTC_train, BTC_test = output_var[:len(train_index)].values.ravel(), output_var[len(train_index): (len(train_index)+len(test_index))].values.ravel()

#Process the data for LSTM
trainBTC =np.array(BTC_train)
testBTC =np.array(BTC_test)
BTC_train = trainBTC.reshape(BTC_train.shape[0], 1, BTC_train.shape[1])
BTC_test = testBTC.reshape(BTC_test.shape[0], 1, BTC_test.shape[1])

import tensorflow as tf
import keras
